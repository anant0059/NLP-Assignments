# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('topics.csv')
df.head()
# Out:
#                                                Topic       Type of topic  \
# 0                  12 years a slave (Motion picture)               title
# 1  16th Street Baptist Church Bombing (Birmingham...  meeting/conference
# 2  16th Street Baptist Church Bombing, Birmingham...        general term
# 3  16th Street Baptist Church Bombing, Birmingham...        general term
# 4                                          1775-1783  chronological term
#
#    BL record ID Type of resource                            Content type  \
# 0      18260815        Monograph                Language material ; Text
# 1      19043352        Monograph                Language material ; Text
# 2      19043352        Monograph                Language material ; Text
# 3      19381865        Monograph  Language material ; Still image ; Text
# 4      19057287        Monograph                Language material ; Text
#
#      Material type BNB number           ISBN                      Name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39865 entries, 0 to 39864
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Topic                       39865 non-null  object
#  1   Type of topic               39865 non-null  object
#  2   BL record ID                39865 non-null  int64
#  3   Type of resource            39865 non-null  object
#  4   Content type                39865 non-null  object
#  5   Material type               39845 non-null  object
#  6   BNB number                  29887 non-null  object
#  7   ISBN                        39047 non-null  object
#  8   Name                        33784 non-null  object
#  9   Dates associated with name  14249 non-null  object
#  10  Type of name                33784 non-null  object
#  11  Role                        11329 non-null  object
#  12  All names                   39722 non-null  object
# ...

# %%
df=df[['Title']]
df.head()
# Out:
#                                                Title
# 0                               Twelve years a slave
# 1  Whites recall the civil rights movement in Bir...
# 2  Whites recall the civil rights movement in Bir...
# 3  Bending toward justice : the Birmingham church...
# 4                                     Crossing point

# %%
sent_list=df.values.tolist()
sent_list[0]
# Out:
# ['Twelve years a slave']

# %%
def str_list(Input_Sentence): 
    output_ = Input_Sentence.split()
    return output_

# %%
sent_word_list=[]
for i in sent_list:
    sent_word_list.append(str_list(i[0]));

# %%
sent_word_list
# Out:
# [['Twelve', 'years', 'a', 'slave'],
#  ['Whites',
#   'recall',
#   'the',
#   'civil',
#   'rights',
#   'movement',
#   'in',
#   'Birmingham',
#   ':',
#   'we',
#   "didn't",
#   'know',
#   'it',
#   'was',
#   'history',
#   'until',
#   'after',
#   'it',
#   'happened'],
#  ['Whites',
#   'recall',
#   'the',
#   'civil',
#   'rights',
#   'movement',
#   'in',
#   'Birmingham',
#   ':',
#   'we',
#   "didn't",
#   'know',
#   'it',
#   'was',
#   'history',
#   'until',
#   'after',
#   'it',
#   'happened'],
#  ['Bending',
#   'toward',
#   'justice',
#   ':',
#   'the',
#   'Birmingham',
#   'church',
#   'bombing',
#   'that',
#   'changed',
#   'the',
#   'course',
#   'of',
#   'civil',
#   'rights'],
#  ['Crossing', 'point'],
#  ['Destiny', 'and', 'race', ':', 'selected', 'writings,', '1840-1898'],
#  ['Through',
#   'darkness',
#   'to',
#   'light',
#   ':',
#   'photographs',
#   'along',
#   'the',
#   'underground',
#   'railroad',
#   ':',
#   'a',
# ...

# %%
dic={}

# %%
def av_size(sentence):
    size=0
    for i in sentence:
        size=size+len(i)
        for j in i:
            dic[j]=1
    return size/len(sentence)

# %%
avarage_size=av_size(sent_word_list)
print(avarage_size)
# Out:
# 11.184974288222751

# %%
unique_words=len(dic)
print(len(dic))
# Out:
# 9924
